# %%
import pandas as pd

# %%
df = pd.read_csv("all_books.csv")

# %%
df

# %%
df.shape

# %%
df.head(15)

# %%
df.columns

# %%
df.index

# %%
df.set_index("category")

# %%
df.set_index("title")

# %%
df

# %%
df.title.head()

# %%
df["title"].head()

# %%
import pandas as pd

# %%
df = pd.read_csv("all_books.csv")
df.head()

# %%
df["title"]

# %%
df["title"].head()

# %%
type(df)

# %%
df.title.head()

# %%
 df[40:50]

# %%
df_email = df.set_index("title")

# %%
df_email

# %%
df_email.loc["The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy"]

# %%
df_email.loc['The Art of Not Breathing']

# %%
import pandas as pd 
df = pd.read_csv("all_books.csv")

# %%
df["category"]
# Out:
# 0           Academic
# 1      Add a comment
# 2      Add a comment
# 3      Add a comment
# 4      Add a comment
#            ...
# 995      Young Adult
# 996      Young Adult
# 997      Young Adult
# 998      Young Adult
# 999      Young Adult
# Name: category, Length: 1000, dtype: object

# %%
dfdf["category"] == "Young Adult"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 dfdf["category"] == "Young Adult"
#
# NameError: name 'dfdf' is not defined

# %%
df["category"] == "Young Adult"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: category, Length: 1000, dtype: bool

# %%
df[df["category"] == "Young Adult"]
# Out:
#                                       product_page_url  \
# 946  http://books.toscrape.com/catalogue/the-requie...
# 947  http://books.toscrape.com/catalogue/set-me-fre...
# 948  http://books.toscrape.com/catalogue/the-natura...
# 949  http://books.toscrape.com/catalogue/obsidian-l...
# 950  http://books.toscrape.com/catalogue/burning_88...
# 951  http://books.toscrape.com/catalogue/a-fierce-a...
# 952  http://books.toscrape.com/catalogue/scarlett-e...
# 953  http://books.toscrape.com/catalogue/nightingal...
# 954  http://books.toscrape.com/catalogue/library-of...
# 955  http://books.toscrape.com/catalogue/frostbite-...
# 956  http://books.toscrape.com/catalogue/wild-swans...
# 957  http://books.toscrape.com/catalogue/until-frid...
# 958  http://books.toscrape.com/catalogue/this-is-wh...
# 959  http://books.toscrape.com/catalogue/the-darkes...
# 960  http://books.toscrape.com/catalogue/my-kind-of...
# 961  http://books.toscrape.com/catalogue/dont-get-c...
# ...
